# %%
import random

import pea
from pea import nn, viz

# %%
x = pea.Value(1.0)
y = (x * 2 + 1).relu()
y.backward()
viz.draw_dot(y)

# %%
random.seed(1337)
n = nn.Neuron(2)
x = [pea.Value(1.0), pea.Value(-2.0)]
y = n(x)[0]
y.backward()
viz.draw_dot(y)
