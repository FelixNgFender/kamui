# %%
import random
import kamui as km
from kamui import viz
from kamui import nn

# %%
x = km.Value(1.0)
y = (x * 2 + 1).relu()
y.backward()
viz.draw_dot(y)

# %%
random.seed(1337)
n = nn.Neuron(2)
x = [km.Value(1.0), km.Value(-2.0)]
y = n(x)
y.backward()
viz.draw_dot(y)
